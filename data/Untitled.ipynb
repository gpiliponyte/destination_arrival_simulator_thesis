# %%
import pandas as pd

# %%
nationalityTrends2010=pd.read_excel(io='../real_data/2010 ARR PRES GG gem naz cat.xlsx', 
                          sheet_name='Nationality')

# %%
nationalityTrends2010 = nationalityTrends2010.fillna(method='ffill', axis=0)

# %%
nationalityTrends2010.head(10)
# Out:
#    Mese di riferimento  Giorno di riferimento Beschreibung Gemeinde  \
# 0                  1.0                    1.0                 Abtei
# 1                  1.0                    1.0                 Abtei
# 2                  1.0                    1.0                 Abtei
# 3                  1.0                    1.0                 Abtei
# 4                  1.0                    1.0                 Abtei
# 5                  1.0                    1.0                 Abtei
# 6                  1.0                    1.0               Ahrntal
# 7                  1.0                    1.0               Ahrntal
# 8                  1.0                    1.0               Ahrntal
# 9                  1.0                    1.0               Ahrntal
#
#             nationaggr3_desc  Arrivi del giorno  Presenti del giorno
# 0              Andere Länder                 33                  365
# 1             Beneluxstaaten                  8                   74
# ...

# %%
nationalityTrends2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 202479 entries, 0 to 202478
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Mese di riferimento    202479 non-null  float64
#  1   Giorno di riferimento  202479 non-null  float64
#  2   Beschreibung Gemeinde  202479 non-null  object
#  3   nationaggr3_desc       202479 non-null  object
#  4   Arrivi del giorno      202479 non-null  int64
#  5   Presenti del giorno    202479 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 9.3+ MB

# %%
nationalityTrends2010.describe()
# Out:
#        Mese di riferimento  Giorno di riferimento  Arrivi del giorno  \
# count        202479.000000          202479.000000      202479.000000
# mean              6.513283              15.706676          28.147028
# std               3.296287               8.839149          90.222881
# min               1.000000               1.000000           0.000000
# 25%               4.000000               8.000000           0.000000
# 50%               7.000000              16.000000           4.000000
# 75%               9.000000              23.000000          19.000000
# max              12.000000              31.000000        3379.000000
#
#        Presenti del giorno
# count        202479.000000
# mean            141.152865
# std             393.927855
# min               0.000000
# 25%               6.000000
# 50%              23.000000
# 75%              94.000000
# max            7098.000000

# %%
catTrends2010=pd.read_excel(io='../real_data/2010 ARR PRES GG gem naz cat.xlsx', 
                          sheet_name='Category')

# %%
catTrends2010 = catTrends2010.fillna(method='ffill', axis=0)

# %%
catTrends2010.head(10)
# Out:
#    Mese di riferimento  Giorno di riferimento  \
# 0                  1.0                    1.0
# 1                  1.0                    1.0
# 2                  1.0                    1.0
# 3                  1.0                    1.0
# 4                  1.0                    1.0
# 5                  1.0                    1.0
# 6                  1.0                    1.0
# 7                  1.0                    1.0
# 8                  1.0                    1.0
# 9                  1.0                    1.0
#
#   Beschreibung Bezirksgemeinschaft             ctt1aggr_desc  \
# 0                            Bozen                1-2 Sterne
# 1                            Bozen                  3 Sterne
# 2                            Bozen                4-5 Sterne
# 3                            Bozen           Andere Betriebe
# 4                            Bozen           Privatquartiere
# 5                            Bozen  Urlaub auf dem Bauernhof
# ...

# %%
catTrends2010.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23196 entries, 0 to 23195
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Mese di riferimento               23196 non-null  float64
#  1   Giorno di riferimento             23196 non-null  float64
#  2   Beschreibung Bezirksgemeinschaft  23196 non-null  object
#  3   ctt1aggr_desc                     23196 non-null  object
#  4   Arrivi del giorno                 23196 non-null  int64
#  5   Presenti del giorno               23196 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.1+ MB

# %%
catTrends2010.describe()
# Out:
#        Mese di riferimento  Giorno di riferimento  Arrivi del giorno  \
# count         23196.000000           23196.000000       23196.000000
# mean              6.533928              15.706975         245.696758
# std               3.391799               8.807244         515.689308
# min               1.000000               1.000000           0.000000
# 25%               4.000000               8.000000          17.000000
# 50%               7.000000              16.000000          74.000000
# 75%               9.000000              23.000000         245.000000
# max              12.000000              31.000000       12954.000000
#
#        Presenti del giorno
# count         23196.000000
# mean           1232.130152
# std            2144.118683
# min               0.000000
# 25%             115.000000
# 50%             400.000000
# 75%            1310.250000
# max           19858.000000

# %%
catTrends2010Strange=pd.read_excel(io='../real_data/2010 ARR PRES GG gem naz cat.xlsx', 
                          sheet_name='DiffCat')

# %%
catTrends2010Strange = catTrends2010Strange.fillna(method='ffill', axis=0)

# %%
catTrends2010Strange.head(10)
# Out:
#    Mese di riferimento  Giorno di riferimento verband_desc  \
# 0                  1.0                    1.0   Alta Badia
# 1                  1.0                    1.0   Alta Badia
# 2                  1.0                    1.0   Alta Badia
# 3                  1.0                    1.0   Alta Badia
# 4                  1.0                    1.0   Alta Badia
# 5                  1.0                    1.0   Alta Badia
# 6                  1.0                    1.0   Alta Badia
# 7                  1.0                    1.0   Alta Badia
# 8                  1.0                    1.0     Eggental
# 9                  1.0                    1.0     Eggental
#
#                  ctt1aggr_desc  Arrivi del giorno  Presenti del giorno
# 0                   1-2 Sterne                154                 2654
# 1                     3 Sterne                246                 4217
# 2                   4-5 Sterne                236                 3070
# ...

# %%
catTrends2010Strange.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28652 entries, 0 to 28651
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Mese di riferimento    28652 non-null  float64
#  1   Giorno di riferimento  28652 non-null  float64
#  2   verband_desc           28652 non-null  object
#  3   ctt1aggr_desc          28652 non-null  object
#  4   Arrivi del giorno      28652 non-null  int64
#  5   Presenti del giorno    28652 non-null  int64
# dtypes: float64(2), int64(2), object(2)
# memory usage: 1.3+ MB

# %%
catTrends2010Strange.describe()
# Out:
#        Mese di riferimento  Giorno di riferimento  Arrivi del giorno  \
# count         28652.000000           28652.000000       28652.000000
# mean              6.496126              15.723929         198.910443
# std               3.408034               8.814015         394.643517
# min               1.000000               1.000000           0.000000
# 25%               4.000000               8.000000          11.000000
# 50%               7.000000              16.000000          57.000000
# 75%               9.000000              23.000000         196.000000
# max              12.000000              31.000000        7628.000000
#
#        Presenti del giorno
# count         28652.000000
# mean            997.504223
# std            1586.706009
# min               0.000000
# 25%              89.000000
# 50%             374.000000
# 75%            1249.000000
# max           14075.000000
